# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
import json

from keras.preprocessing.text import tokenizer_from_json
from keras import models
from keras.preprocessing import sequence

from IPython.display import clear_output
# Out:
# Using TensorFlow backend.

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %%
key = 'd94a78dfff40a2ec008d5b81eec15938'

model = models.load_model('model_textcnn_imbd.h5')

maxlen = 2493

with open('tokenizer.json') as f:
    data = json.load(f)
    tokenizer = tokenizer_from_json(data)

# %%
def model_apply(lst_reviews):
    tokenize_reviews = tokenizer.texts_to_sequences(lst_reviews)
    sequence_reviews = sequence.pad_sequences(tokenize_reviews, padding = 'pre', 
                                         truncating = 'post', maxlen=maxlen)
    predict_reviews = model.predict(sequence_reviews)
    positive_reviews = 0
    negative_reviews = 0
    for predict_review in predict_reviews:
        if predict_review[0] > 0.5:
            positive_reviews += 1
        else:
            negative_reviews += 1
    print(color.BOLD + f"This movie has {positive_reviews} positive reviews and {negative_reviews} negative reviews" + color.END)

# %%
def examine_reviews(result):
    lst_reviews = []
    movie_id = result['id']
    url = f"https://api.themoviedb.org/3/movie/{movie_id}/reviews?api_key={key}&language=en-US"
    r = requests.get(url)
    json = r.json()
    total_results = json['total_results']
    if total_results == 0:
        print(color.BOLD + 'There are not reviews for this movie' + color.END)
    else:
        print(color.BOLD + f'This movie have {total_results} reviews' + color.END)
        for review in json['results']:
            lst_reviews.append(review['content'])
        model_apply(lst_reviews)

# %%
def main():
    correct = True
    num_search = 0
    cont = 0

    movie = input(color.BOLD + 'Enter the name of a movie: ' + color.END)
    url = f'https://api.themoviedb.org/3/search/movie?api_key={key}&query={movie}'
    r = requests.get(url)

    json = r.json()
    num_search = len(json['results'])
    
    if num_search == 0:
        print(color.BOLD + "I can't find the movie, try it again" + color.END)

    while correct and num_search > 0:
        result = json['results'][cont]
        poster = result['poster_path']
        url_image = f'https://image.tmdb.org/t/p/w400/{poster}'
        response = requests.get(url_image)
        img = Image.open(BytesIO(response.content))
        plt.figure(figsize=(20,10))
        plt.axis('off')
        imgplot = plt.imshow(img)
        plt.show()
        answer = input(color.BOLD + "Is it this movie? Type yes/no\n" + color.END) 
        if answer == 'yes':
            examine_reviews(result)
            break
        elif answer == 'no':
            cont += 1
            num_search -= 1
            clear_output(wait=True)
            continue
        else:
            print(color.BOLD + 'An error occurred' + color.END)
            break

        if num_search == 0:
            print(color.BOLD + "I can't find the movie, try it again" + color.END)
            break

# %%
main()
# Out:
# Enter the name of a movie: joker
# Is it this movie? Type yes/no
# yes
# This movie have 10 reviews
# This movie has 9 positive reviews and 1 negative reviews
